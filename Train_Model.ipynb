# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np
# Out:
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
TRAIN_DIR = r"C:\PYthon\FACE_EMOTION\images\train"
TEST_DIR = r"C:\PYthon\FACE_EMOTION\images\test"

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                                    image     label
# 0        C:\PYthon\FACE_EMOTION\images\train\angry\0.jpg     angry
# 1        C:\PYthon\FACE_EMOTION\images\train\angry\1.jpg     angry
# 2       C:\PYthon\FACE_EMOTION\images\train\angry\10.jpg     angry
# 3      C:\PYthon\FACE_EMOTION\images\train\angry\1000...     angry
# 4      C:\PYthon\FACE_EMOTION\images\train\angry\1001...     angry
# ...                                                  ...       ...
# 28816  C:\PYthon\FACE_EMOTION\images\train\surprise\9...  surprise
# 28817  C:\PYthon\FACE_EMOTION\images\train\surprise\9...  surprise
# 28818  C:\PYthon\FACE_EMOTION\images\train\surprise\9...  surprise
# 28819  C:\PYthon\FACE_EMOTION\images\train\surprise\9...  surprise
# 28820  C:\PYthon\FACE_EMOTION\images\train\surprise\9...  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
# Out:
#                                                   image     label
# 0     C:\PYthon\FACE_EMOTION\images\test\angry\10052...     angry
# 1     C:\PYthon\FACE_EMOTION\images\test\angry\10065...     angry
# 2     C:\PYthon\FACE_EMOTION\images\test\angry\10079...     angry
# 3     C:\PYthon\FACE_EMOTION\images\test\angry\10095...     angry
# 4     C:\PYthon\FACE_EMOTION\images\test\angry\10121...     angry
# ...                                                 ...       ...
# 7061  C:\PYthon\FACE_EMOTION\images\test\surprise\98...  surprise
# 7062  C:\PYthon\FACE_EMOTION\images\test\surprise\98...  surprise
# 7063  C:\PYthon\FACE_EMOTION\images\test\surprise\98...  surprise
# 7064  C:\PYthon\FACE_EMOTION\images\test\surprise\98...  surprise
# 7065  C:\PYthon\FACE_EMOTION\images\test\surprise\99...  surprise
#
# [7066 rows x 2 columns]

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale =  True )
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features = extract_features(test['image'])

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])
